# %%
import os
import glob
import re
import configparser
import pandas as pd
import numpy as np
import xlwings as xl
import xlsxwriter

# %% [markdown]
# 1. 读取AMSA全部的数据，将数据按照35 site 进行平均值的计算。

# %%
AMSA_file_path='C:/Users/wanglinl/Desktop/Linlin/2_Code_Temp/ACC_Project/AMSA.xlsx'
data=pd.read_excel(AMSA_file_path,sheet_name=None)

writer = pd.ExcelWriter('AMSA1.xlsx', engine='xlsxwriter')

for sheet_name,df in data.items():

    if 'SENS' in df.columns:
        df = df.groupby('site_num')['SENS'].mean().reset_index()
    elif df.columns.str.contains('PHASE').any():
        df = df.groupby('site_num')[df.columns[df.columns.str.contains('PHASE')]].mean().reset_index()
    elif df.columns.str.contains('THD').any():
        df = df.groupby('site_num')[df.columns[df.columns.str.contains('THD')]].mean().reset_index()


    sheet_name = sheet_name.replace('Hz', '')
    

    df.to_excel(writer, sheet_name=sheet_name, index=False)



writer.save()
# Out:
# C:\Users\wanglinl\AppData\Local\Temp\ipykernel_17456\2326233193.py:28: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %%
# %run A301_AMSA1_Edit.ipynb
# %run A400_0_ReadSpkVol_good.ipynb
# %run A401_AllCompensation.ipynb

# %run A500_Final_ACC_File.ipynb - 已经去掉。不用单独生成ACC 文件，直接生成在了New ACC 中
# Out:
# THD_94dBSPL
# THD_100dBSPL
# THD_106dBSPL
# THD_112dBSPL
# THD_118dBSPL
# THD_124dBSPL
# THD_127dBSPL
# THD_130dBSPL
# 20
# 35
# Phase_75
# 80
# 300
# Phase_300
# 900
# 1000
# Phase_1000
# 1100
# 3000
# Phase_3000
# 8000
# 10000
# Phase_10000
# THD_94dBSPL
# THD_100dBSPL
# THD_106dBSPL
# THD_112dBSPL
# THD_118dBSPL
# THD_124dBSPL
# THD_127dBSPL
# THD_130dBSPL
# 20
# 35
# Phase_75
# 80
# 300
# Phase_300
# 900
# 1000
# Phase_1000
# 1100
# 3000
# Phase_3000
# 8000
# 10000
# Phase_10000
# THD_94dBSPL
# THD_100dBSPL
# THD_106dBSPL
# THD_112dBSPL
# THD_118dBSPL
# THD_124dBSPL
# THD_127dBSPL
# THD_130dBSPL
# 20
# 35
# Phase_75
# 80
# 300
# Phase_300
# 900
# 1000
# Phase_1000
# 1100
# 3000
# Phase_3000
# 8000
# 10000
# Phase_10000
# THD_94dBSPL
# THD_100dBSPL
# THD_106dBSPL
# THD_112dBSPL
# THD_118dBSPL
# THD_124dBSPL
# THD_127dBSPL
# THD_130dBSPL
# 20
# 35
# Phase_75
# phaseok
# 80
# 300
# Phase_300
# 900
# 1000
# Phase_1000
# 1100
# 3000
# Phase_3000
# 8000
# 10000
# Phase_10000
# ...

# %%
# def ini_target_value():
#     df = pd.read_excel('C:/Users/wanglinl/Desktop/Linlin/2_Code_Temp/ACC_Project/AMSA1.xlsx', sheet_name=None)
#     # print(amsa_doc)

#     # 读取New_ini_Target文档
#     new_ini_doc = pd.read_excel('C:/Users/wanglinl/Desktop/Linlin/2_Code_Temp/ACC_Project/New_ini_Target.xlsx', sheet_name=None)
#     # print(new_ini_doc)

#     # 遍历AMSA文档中的所有sheet
#     for sheet_name, ini_sheet in new_ini_doc.items():
#         # 如果当前sheet的名字不是'94'，则跳过
#         if sheet_name != '94':
#             continue

#         # 获取当前sheet中所有不重复的freq值
#         freq_values = ini_sheet['Freq'].unique()
#         # print(freq_values)

#         #获取相对应的value列的读值
#         for freq in freq_values:
#             value = ini_sheet.loc[ini_sheet['Freq'] == freq, 'Value'].values[0]

#             freq=int(freq)
#             # print(freq)
#             # print(value)

#             for sheet_name2, amsa_sheet in df.items():
#                 if str(freq) in sheet_name2:
#                     amsa_sheet.loc[:, 'New_Target'] = value

#                 else:
#                     pass

# %%
# def write_values_to_amsa1():
#     # 读取AMSA文档
#     amsa_doc = pd.read_excel('path/to/AMSA.xlsx', sheet_name=None)

#     # 读取New_ini_Target文档
#     new_ini_doc = pd.read_excel('path/to/New_ini_Target.xlsx', sheet_name=None)

#     # 遍历AMSA文档中的所有sheet
#     for sheet_name, amsa_sheet in amsa_doc.items():
#         # 如果当前sheet的名字不是'94'，则跳过
#         if sheet_name != '94':
#             continue

#         # 获取当前sheet中所有不重复的freq值
#         freq_values = amsa_sheet['freq'].unique()

#         # 遍历每个freq值
#         for freq_value in freq_values:
#             # 在New_ini_Target文档中查找与当前freq值匹配的行
#             matching_rows = new_ini_doc[sheet_name][new_ini_doc[sheet_name]['Freq'] == freq_value]

#             # 如果找到匹配的行，则将相应的value值写入到AMSA文档的当前sheet中
#             if not matching_rows.empty:
#                 matching_values = matching_rows['Value'].values
#                 amsa_sheet.loc[amsa_sheet['freq'] == freq_value, 'value'] = matching_values

#     # 将更新后的AMSA文档保存到磁盘
#     amsa_doc.to_excel('path/to/updated_AMSA.xlsx', index=False)
